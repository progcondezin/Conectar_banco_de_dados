# %%
import pandas as pd
import sqlalchemy
import pymssql

# %%
engine = sqlalchemy.create_engine("mssql+pymssql://user-VWC:#VetWeCare#@192.168.101.14/DW")

# %%
#1- Puxar todo histórico da pontuação por período
#2- Opção por data de pagamento e por data de procedimento

query = '''
    SELECT * 
    FROM VWCTLPGT
    WHERE DATFEC >= '20230801' AND DATFEC <='20501231'
    AND ORGBAS = 1
    '''

#DATFEC >= '20221101' AND DATFEC <='20221231 (data de pagamento)
#DATPCD > = '20220601 00:00:00' AND DATPCD <= '20501231 23:59:59' (Data de procedimento)

# %%
#Filtrar pagamento realizados por ficha

query = '''
    SELECT * 
    FROM VWCTLPGT
    WHERE CODANI = '211729'
    '''

# %%
#Filtrar POR UNIDADE (1 Pet Care / 2 Animália)

query = '''
    SELECT * 
    FROM VWCTLPGT
    WHERE DATFEC >= '20230705' AND DATFEC <='20230712'
    AND ORGBAS = 2
    '''

# %%
#Filtrar por CRMV do vet

query = '''
    SELECT * 
    FROM VWCTLPGT
    WHERE DATFEC >= '20230619' AND DATFEC <='20230624'
    AND NUMCRV = '8472'
    '''

# %%
#Filtrar por PA

query = '''
    SELECT * 
    FROM VWCTLPGT
    WHERE DATFEC >= '20220501' AND DATFEC <='20231213'
    AND NUMOSS = '521881'
    '''

# %%
df = pd.read_sql_query(query, engine)
df
# Out:
#      NIDPCD  ORGBAS   DSCEMP  STAREC  STACSL  NUMOSS              DATPCD  \
# 0   3149744       1  Jardins       1       0  542185 2023-07-22 13:04:00
# 1   3149744       1  Jardins       1       0  542185 2023-07-22 13:04:00
# 2   3149538       1  Jardins       1       0  542071 2023-07-22 10:59:21
# 3   3149437       1  Jardins       1       1  542071 2023-07-22 10:12:57
# 4   3149437       1  Jardins       1       1  542071 2023-07-22 10:12:57
# 5   3149437       1  Jardins       1       1  542071 2023-07-22 10:12:57
# 6   3149437       1  Jardins       1       1  542071 2023-07-22 10:12:57
# 7   3149437       1  Jardins       1       1  542071 2023-07-22 10:12:57
# 8   3149548       1  Jardins       1       0  542071 2023-07-22 11:03:06
# 9   3149548       1  Jardins       1       0  542071 2023-07-22 11:03:06
# 10  3149538       1  Jardins       1       0  542071 2023-07-22 10:59:21
#
#     CODPCD                          DSCPCD  CODANI  ... VETKEY        DSCVET  \
# ...

# %%
df.to_excel(r'Y:\12-Vet We Care\Pontos\pontuação.xlsx',index=False)
